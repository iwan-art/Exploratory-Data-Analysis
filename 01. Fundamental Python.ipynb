# %% [markdown]
# # Python Fundamental

# %% [markdown]
# https://docs.python.org/3/tutorial/index.html

# %% [markdown]
# https://belajarpython.com/tutorial/apa-itu-python

# %% [raw]
# Mulai belajar python dengan mengenal tipe data

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("Hello World") # fungsi print --> menampilkan objek
# Out:
# Hello World

# %% [markdown]
# ##### string dan integer

# %%
print("kita akan memulai") # string memerlukan tanda petik
# Out:
# kita akan memulai

# %%
print(43) # angka tidak memerlukan tanda petik
# Out:
# 43

# %% [markdown]
# ### assignment

# %% [raw]
# - Memasukkan sebuah value ke dalam variabel

# %%
nama = "Rahwana" # nama merupakan sebuah variabel yg di isi nilai
usia = 21        
pendekar = True

# %%
print(nama)      # akan menampilkan isi dari variabel nama
print(usia)      # akan menampilkan isi dari variabel usia
print(pendekar)  # akan menampilkan isi dari variabel pendekar
# Out:
# Rahwana
# 21
# True

# %% [markdown]
# ### mutiple assignment

# %%
a,b = 2,3

# %%
a
# Out:
# 2

# %%
b
# Out:
# 3

# %%
a,b = b,a

# %%
a
# Out:
# 3

# %%
x = y = z = "cool"

# %%
x
# Out:
# 'cool'

# %%
y
# Out:
# 'cool'

# %% [markdown]
# ### Tipe Data

# %% [raw]
# Mengetahui tipe data dari variabel

# %%
print(type(nama))    # akan menampilkan tipe data dari variabel nama
print(type(usia))
print(type(pendekar))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'bool'>

# %% [markdown]
# ### Input

# %% [raw]
# Input mempunyai fungsi untuk mendapatkan feedback dari user

# %%
question = input("wani piro? ") # input akan menghasilkan tipe data string
print(question)                 # walaupun di isi dengan angka, tipe data nya berbentuk string
# Out:
# wani piro? 54
# 54

# %%
print(type(question))
# Out:
# <class 'str'>

# %%
utang = int(input("punya duit berapa?"))  # bisa berbentuk int, dengan menambahkan "int" sebelum "input"

print(utang)
# Out:
# punya duit berapa?33
# 33

# %%
print(type(utang))
# Out:
# <class 'int'>

# %%
Nama = input("Siapa nama kamu? ")
Umur = int(input("Berapa usia kamu? "))
Gender = input("Apa jenis kelamin kamu? ")
Job = input("Apa pekerjaan kamu? ")

print("Nama: ",Nama)
print("Umur: ",Umur)
print("Kelamin: ",Gender)
print("Pekerjaan: ",Job)
# Out:
# Siapa nama kamu? Arjuna
# Berapa usia kamu? 24
# Apa jenis kelamin kamu? Pria
# Apa pekerjaan kamu? Dosen
# Nama:  Arjuna
# Umur:  24
# Kelamin:  Pria
# Pekerjaan:  Dosen

# %%
name = "lucas"

# %%
name + " moreno"
# Out:
# 'lucas moreno'

# %%
name * 2
# Out:
# 'lucaslucas'

# %%
"rudiyono"
# Out:
# 'rudiyono'

# %% [markdown]
# ### String Indexing

# %% [raw]
# - Index dimulai dari angka 0
# - [awal:akhir:step]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
text = "I'm Baron, nice to meet you"

# %%
print(text[:])
print(text[1])   # index ke 1
print(text[2:])  # mengambil dari index ke 2 sampai akhir
print(text[:4])  # index awal sampai ke (4-1)
print(text[2:5]) # index 2 sampai ke (5-1)
# Out:
# I'm Baron, nice to meet you
# '
# m Baron, nice to meet you
# I'm
# m B

# %%
print(text[-4:])
print(text[0:-6])
print(text[-3:-2])
# Out:
#  you
# I'm Baron, nice to me
# y

# %%
print(text[1:8:2])
# Out:
# ' ao

# %%
print(text[::-1])
# Out:
# uoy teem ot ecin ,noraB m'I

# %%
print(text[-8:-1:1])
# Out:
# meet yo

# %% [markdown]
# ## Operasi Aritmatika

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# - operasi aritmatika pada python juga mengikuti aturan matematika
# - seperti mendahulukan perkalian

# %%
2 * 3
# Out:
# 6

# %%
nilai = 93

# %%
nilai - 78
# Out:
# 15

# %%
nilai / 12
# Out:
# 7.75

# %%
nilai // 12
# Out:
# 7

# %%
nilai % 2
# Out:
# 1

# %%
nilai ** 2
# Out:
# 8649

# %% [raw]
# - Jika dibutuhkan pyhton juga memiliki memiliki library Matematika
# - Dimana sudah disediakan beberapa fungsi bawaan

# %% [markdown]
# #### Library math

# %%
# memanggil library dengan cara import

import math

# %%
print(math.pi)         # bilangan pi (22/7)
print(math.fabs(-4.7)) # nilai absolute (menjadikan nilai negatif -> positif)
print(math.pow(8, 2))  # power (sama seperti pangkat)
print(math.sqrt(64))   # mencari nilai akar
# Out:
# 3.141592653589793
# 4.7
# 64.0
# 8.0

# %%
print(round(4.7))      # pembulatan (>5 ke atas) #BILANGAN GANJIL DI GENAPKAN KE ATAS #GENAP -> BAWAH
print(round(4.4))      # pembulatan (< 5 kebawah)
print(math.floor(4.7)) # pembulatan ke bawah
print(math.ceil(4.4))  # pembulatan ke atas
# Out:
# 5
# 4
# 4
# 5

# %% [markdown]
# # Exercise

# %% [markdown]
# ## Solve it!

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = 4
y = 3
z = 2

w = ((x+y*z)/(x*y))**z
print(w)
# Out:
# 0.6944444444444445

# %% [markdown]
# ## Solve it!

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Angka = int(input("Silahkan masukkan angka berapapun: "))

print("Kuadrat dari ", Angka, "=", Angka*Angka)
# Out:
# Silahkan masukkan angka berapapun: 4
# Kuadrat dari  4 = 16
